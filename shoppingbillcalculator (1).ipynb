# %%
print("     Shopping Bill      ")
print("                        ")
item1=str(input("enter a item"))
price1=float(input("enter a price"))
qty1=int(input("enter a Quantity"))
total1=price1*qty1

print("                        ")

item2=str(input("enter a item"))
price2=float(input("enter a price"))
qty2=int(input("enter a Quantity"))
total2=price2*qty2

print("                        ")

item3=str(input("enter a item"))
price3=float(input("enter a price"))
qty3=int(input("enter a Quantity"))
total3=price3*qty3

print("                        ")

item4=str(input("enter a item"))
price4=float(input("enter a price"))
qty4=int(input("enter a Quantity"))
total4=price4*qty4

print("                        ")

item5=str(input("enter a item"))
price5=float(input("enter a price"))
qty5=int(input("enter a Quantity"))
total5=price5*qty5

print("                        ")

totalamount=total1+total2+total3+total4+total5
print("TotalAmount=",totalamount)
print("                        ")
print("       ThankYou😊       ")
# Out:
#      Shopping Bill
# enter a item chips
# enter a price 10
# enter a Quantity 5
# enter a item chocolate
# enter a price 50
# enter a Quantity 2
# enter a item buttermilk
# enter a price 20
# enter a Quantity 5
# enter a item cookies
# enter a price 30
# enter a Quantity 3
# enter a item icecream
# enter a price 70
# enter a Quantity 2
#
# TotalAmount= 480.0
#
#        ThankYou😊
